# %%
#Samir Sudhir Babar
#Ass no 2(c)
#importing libraries and basic libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

loadinf_dt=sns.load_dataset('titanic')
loadinf_dt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#using some function like head,tail,shape and column
#first 5 rows
print(loadinf_dt.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(loadinf_dt.tail()) # last 5 rows of dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
print(loadinf_dt.shape) #shape of dataset
# Out:
# (891, 15)

# %%
loadinf_dt.columns  #which are column present there
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#using describe function tosee mean ,mode,median,IQR ETC things
loadinf_dt.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#using isnullsum function to see column with no. of null values
loadinf_dt.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#Data Preprocessing
#fiiling missing values
#age and deck
newdt=loadinf_dt
newdt['age'].fillna(newdt['age'].mean(),inplace=True)

# Check if 'unknown' is already a category
if 'unknown' not in newdt['deck'].cat.categories:
  # Add 'unknown' to the categories of the 'deck' column if it doesn't exist
  newdt['deck'] = newdt['deck'].cat.add_categories('unknown')

# Now you can fill the missing values with 'unknown'
newdt['deck'].fillna('unknown', inplace=True)
newdt['embark_town'].fillna('sanfransisco',inplace=True)
newdt['embarked'].fillna('S',inplace=True)

newdt
# Out:
# <ipython-input-4-c3334a5ef9a6>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   newdt['age'].fillna(newdt['age'].mean(),inplace=True)
# <ipython-input-4-c3334a5ef9a6>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
newdt.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
box1=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot with outliers')
plt.show()

# %%
#here handling outliers
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()

# %%
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()

# %%
Q1=newdt['fare'].quantile(0.25)
Q3=newdt['fare'].quantile(0.75)
IQR=Q3-Q1

#setting th bounds

lowerbound= Q1-1.5*IQR
upperbound= Q3+1.5*IQR

#selecting region of 0.25 quintile to 0.75 quintile
datasetfiltered =newdt[(newdt['fare']>=lowerbound) & (newdt['fare']<=upperbound)]
meannn=datasetfiltered['fare'].mean()
#replacing all values which are out ot the ).25 quintile and 0.75 by meannn
newdt.loc[(newdt['fare']<lowerbound) | (newdt['fare']>upperbound),'fare']=meannn

#new ploting boxplot without outliers
box2=sns.boxplot(x=newdt['fare'],color="maroon")
plt.xlabel('fare')
plt.title('boxplot without outliers')
plt.show()
