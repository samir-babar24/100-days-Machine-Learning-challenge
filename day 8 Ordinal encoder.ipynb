# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import accuracy_score

# %%
df=sns.load_dataset("diamonds")
df.sample(20)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 19049   0.30  Very Good     E    VVS2   59.7   57.0    622  4.37  4.43  2.62
# 48101   0.50      Ideal     G    VVS2   62.0   56.0   1935  5.13  5.09  3.17
# 8892    0.92      Ideal     I     SI1   61.8   57.0   4488  6.22  6.27  3.86
# 23970   2.01    Premium     J     SI2   62.4   59.0  12105  8.05  8.10  5.04
# 18388   0.29  Very Good     E     VS1   59.2   58.0    619  4.36  4.39  2.59
# 8267    0.90    Premium     D     SI1   62.7   58.0   4381  6.09  6.15  3.84
# 33727   0.41  Very Good     H    VVS2   61.3   54.0    839  4.75  4.87  2.95
# 26949   2.06    Premium     G     SI2   61.7   58.0  17012  8.20  8.15  5.04
# 20631   1.39    Premium     F     SI1   62.4   59.0   8925  7.14  7.09  4.44
# 10450   1.14    Premium     I     SI1   59.1   58.0   4788  6.83  6.81  4.03
# 33810   0.32      Ideal     G    VVS1   62.4   56.0    842  4.36  4.39  2.73
# ...

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df['cut'].unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
inp=df.loc[:,'cut']
inp
out=df.iloc[:,-4]
out
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(inp,out,test_size=0.2,random_state=20)
oe= OrdinalEncoder(categories=[['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']])
oe.fit(x_train)
x_transformed=oe.transform(x_train)
x_transformed_test=oe.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-0d3a1e621b46> in <cell line: 0>()
#       1 x_train,x_test,y_train,y_test=train_test_split(inp,out,test_size=0.2,random_state=20)
#       2 oe= OrdinalEncoder(categories=[['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']])
# ----> 3 oe.fit(x_train)
#       4 x_transformed=oe.transform(x_train)
#       5 x_transformed_test=oe.transform(x_test)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#    1513
#    1514         # `_fit` will only raise an error when `self.handle_unknown="error"`
# ...
