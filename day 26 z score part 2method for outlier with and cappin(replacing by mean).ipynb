# %%
#using z suqre method for ouotlier detection  and filliing using cap method

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/travel-times.csv")

# %%
df

# %%
sam=df.drop(columns=['Date', 'StartTime', 'DayOfWeek', 'GoingTo', 'TotalTime', 'MovingTime',
       'Take407All', 'Comments','FuelEconomy'])

# %%
# lets work distance
sam_cg_std=sam['Distance'].std()
sam_cg_mean=sam['Distance'].mean()

print("std=",sam_cg_std," \n\nmean =",sam_cg_mean)
# Out:
# std= 1.3212053157515522
#
# mean = 50.981512195121944

# %%
#capping and replacinng
upeer_limit=sam_cg_mean+3*sam_cg_std
lower_limit=sam_cg_mean-3*sam_cg_std

print("upeer limit=",upeer_limit,"\n\nlower limit=",lower_limit)
# Out:
# upeer limit= 54.9451281423766
#
# lower limit= 47.017896247867284

# %%
sam['Distance']=np.where(sam['Distance']>upeer_limit,sam_cg_mean
                         ,np.where(sam['Distance']<lower_limit,sam_cg_mean,sam['Distance']))

# %%
sns.histplot(sam['Distance'],fill=True,kde=True,color="red")

plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['Distance'],fill=True,kde=True,color="blue")
plt.title('Distance Distribution')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.show()

# %%
sam['Distance'].mean()
# Out:
# 50.952245152608555

# %%
sam['Distance'].std()
# Out:
# 1.169637040236936

# %%
upeer_limit=sam_cg_mean+3*sam_cg_std
lower_limit=sam_cg_mean-3*sam_cg_std

print("upeer limit=",upeer_limit,"\n\nlower limit=",lower_limit)
# Out:
# upeer limit= 54.9451281423766
#
# lower limit= 47.017896247867284

# %%
sam['Distance']=np.where(sam['Distance']>upeer_limit,sam_cg_mean
                         ,np.where(sam['Distance']<lower_limit,sam_cg_mean,sam['Distance']))

# %%
sns.histplot(sam['Distance'],fill=True,kde=True,color="red")

plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.show()
