# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,mean_absolute_error,mean_squared_error,r2_score
from sklearn.linear_model import
from sklearn.preprocessing import StandardScaler

# %%
d=pd.read_csv("/content/diabetes.csv")

# %%
d.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 373            2      105             58             40       94  34.9
# 569            0      121             66             30      165  34.3
# 286            5      155             84             44      545  38.7
# 366            6      124             72              0        0  27.6
# 300            0      167              0              0        0  32.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 373                     0.225   25        0
# 569                     0.203   33        1
# 286                     0.619   34        0
# 366                     0.368   29        1
# 300                     0.839   30        1

# %%
d.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
d.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
x = d.drop(["Age"], axis=1)
y=d['Age']

# %%
xtr,xte,ytr,yte=train_test_split(x,y,test_size=0.3,random_state=30)

# %%
model=LinearRegression()
model.fit(xtr,ytr)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xte)

# %%
ypred
# Out:
# array([27.61974543, 28.49456334, 43.53916206, 29.0537506 , 34.37224827,
#        28.49662812, 40.569337  , 28.25466679, 26.10110079, 26.51643864,
#        24.7205856 , 34.41531926, 24.52223594, 27.40706747, 37.34834554,
#        24.80001226, 30.12776979, 30.2251523 , 42.6872656 , 42.9980285 ,
#        38.02395701, 40.30887976, 30.29772409, 26.3693544 , 45.85259755,
#        32.71963186, 29.74504093, 38.10970096, 29.56497596, 36.88170178,
#        26.39205166, 34.25347721, 25.19525854, 33.93107231, 27.03253829,
#        25.83282719, 46.18704711, 49.13322256, 49.50027967, 32.05317304,
#        28.18579445, 30.36721759, 33.2475334 , 35.48738796, 50.14425512,
#        47.42578672, 44.87880135, 24.33984018, 27.31429154, 25.97026096,
#        26.73151901, 43.84719947, 35.49117352, 48.95361309, 39.76263003,
#        36.63522549, 49.24955516, 35.19638916, 34.8072533 , 29.44799287,
#        30.80322298, 27.9075868 , 45.66058123, 31.67957191, 25.22111538,
# ...

# %%
accuracy=model.score(xte,yte)
print(accuracy)
# Out:
# 0.40792321875137494

# %%
mae=mean_absolute_error(yte,ypred)
print(mae)
# Out:
# 6.360783530232124

# %%
mse=mean_squared_error(yte,ypred)
print(mse)
# Out:
# 70.14262981233946

# %%
r2=r2_score(yte,ypred)
print(r2)
# Out:
# 0.40792321875137494

# %%
user_input = {
    "Pregnancies": int(input("Enter the Pregnancies: ")),
    "Glucose": int(input("Enter the Glucose: ")),
    "BloodPressure": int(input("Enter the BloodPressure: ")),
    "SkinThickness": int(input("Enter the SkinThickness: ")),
    "Insulin": int(input("Enter the Insulin: ")),
    "BMI": float(input("Enter the BMI: ")),
    "DiabetesPedigreeFunction": float(input("Enter the DiabetesPedigreeFunction: ")),
    "Outcome": int(input("Enter the Outcome: "))
}

# Convert the user input to a DataFrame with the correct column names
user_input_df = pd.DataFrame([user_input])
# Out:
# Enter the Pregnancies: 2
# Enter the Glucose: 100
# Enter the BloodPressure: 50
# Enter the SkinThickness: 6
# Enter the Insulin: 2
# Enter the BMI: 20
# Enter the DiabetesPedigreeFunction: 0.223
# Enter the Outcome: 1

# %%
# Now you can use this DataFrame for prediction
ypred_new = model.predict(user_input_df)

# %%
ypred_new
# Out:
# array([30.87347192])
