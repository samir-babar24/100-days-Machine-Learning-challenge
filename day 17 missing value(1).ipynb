# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('mpg')

# %%
df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 127  19.0          6         232.0       100.0    2901          16.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 40   14.0          8         351.0       153.0    4154          13.5
# 217  30.0          4         111.0        80.0    2155          14.8
# 280  21.5          6         231.0       115.0    3245          15.4
#
#      model_year origin                     name
# 127          74    usa               amc hornet
# 251          78    usa     mercury monarch ghia
# 40           71    usa         ford galaxie 500
# 217          77    usa  buick opel isuzu deluxe
# 280          79    usa        pontiac lemans v6

# %%
#missing percentage
df.isnull().mean()*100
# Out:
# mpg             0.000000
# cylinders       0.000000
# displacement    0.000000
# horsepower      1.507538
# weight          0.000000
# acceleration    0.000000
# model_year      0.000000
# origin          0.000000
# name            0.000000
# dtype: float64

# %%
df['horsepower'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 398 entries, 0 to 397
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 392 non-null    float64
# dtypes: float64(1)
# memory usage: 3.2 KB

# %%
#we will only work on  data which is lesss than 5%
#here we got thw nly single value to remove
#here i have removed all rows with horsepower columns null values

new_df=df['horsepower'].dropna()

# %%
new_df.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 392 entries, 0 to 397
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 392 non-null    float64
# dtypes: float64(1)
# memory usage: 6.1 KB

# %%
SAMM=pd.concat([df.drop(columns=['horsepower']),new_df])

# %%
SAMM.sample(10)
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  origin  \
# 67    NaN        NaN           NaN     NaN           NaN         NaN     NaN
# 227   NaN        NaN           NaN     NaN           NaN         NaN     NaN
# 256  20.5        6.0         225.0  3430.0          17.2        78.0     usa
# 74   13.0        8.0         302.0  4294.0          16.0        72.0     usa
# 322   NaN        NaN           NaN     NaN           NaN         NaN     NaN
# 323  27.9        4.0         156.0  2800.0          14.4        80.0     usa
# 209  19.0        4.0         120.0  3270.0          21.9        76.0  europe
# 382  34.0        4.0         108.0  2245.0          16.9        82.0   japan
# 208  13.0        8.0         318.0  3940.0          13.2        76.0     usa
# 74    NaN        NaN           NaN     NaN           NaN         NaN     NaN
#
#                            name  horsepower
# 67                          NaN       208.0
# ...

# %%
sns.distplot(SAMM['horsepower'])
# Out:
# <ipython-input-21-d6b7ca4f12e3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SAMM['horsepower'])
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.distplot(df['horsepower'])
# Out:
# <ipython-input-22-0df883a519cc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['horsepower'])
# <Axes: xlabel='horsepower', ylabel='Density'>
