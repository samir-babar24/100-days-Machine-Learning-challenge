# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,PolynomialFeatures,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df=pd.read_csv("/content/placement.csv")

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
sam=df.drop(columns=['Unnamed: 0','placement'])

# %%
sam.isnull().sum()
# Out:
# cgpa    0
# iq      0
# dtype: int64

# %%
x = sam[['cgpa']]
y = sam.drop(columns=['cgpa'])

# %%
x
# Out:
#     cgpa
# 0    6.8
# 1    5.9
# 2    5.3
# 3    7.4
# 4    5.8
# ..   ...
# 95   4.3
# 96   4.4
# 97   6.7
# 98   6.3
# 99   6.2
#
# [100 rows x 1 columns]

# %%
y
# Out:
#        iq
# 0   123.0
# 1   106.0
# 2   121.0
# 3   132.0
# 4   142.0
# ..    ...
# 95  200.0
# 96   42.0
# 97  182.0
# 98  103.0
# 99  113.0
#
# [100 rows x 1 columns]

# %%
xtr,xte,ytr,yte=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
slr=LinearRegression()

# %%
slr.fit(xtr,ytr)
# Out:
# LinearRegression()

# %%
pred=slr.predict(xte)

# %%
r2_score(yte,pred)
# Out:
# -0.05299294087887474

# %%
poly=PolynomialFeatures(degree=12)

# %%
xtr_trans=poly.fit_transform(xtr)
xte_trans=poly.transform(xte)

# %%
print(xtr_trans[5])
print(xtr.iloc[5])
# Out:
# [1.00000000e+00 5.10000000e+00 2.60100000e+01 1.32651000e+02
#  6.76520100e+02 3.45025251e+03 1.75962878e+04 8.97410678e+04
#  4.57679446e+05 2.33416517e+06 1.19042424e+07 6.07116362e+07
#  3.09629344e+08]
# cgpa    5.1
# Name: 15, dtype: float64

# %%
print(xte_trans[5])
# Out:
# [1.00000000e+00 4.60000000e+00 2.11600000e+01 9.73360000e+01
#  4.47745600e+02 2.05962976e+03 9.47429690e+03 4.35817657e+04
#  2.00476122e+05 9.22190163e+05 4.24207475e+06 1.95135438e+07
#  8.97623017e+07]

# %%
slr2=LinearRegression()

# %%
slr2.fit(xtr_trans,ytr)
# Out:
# LinearRegression()

# %%
pred1=slr2.predict(xte_trans)

# %%
r2_score(yte,pred1)
# Out:
# -0.06629405450652515

# %%
#hence acuracy is increased
