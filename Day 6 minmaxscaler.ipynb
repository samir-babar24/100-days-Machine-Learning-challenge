# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
sam=sns.load_dataset('tips')
inp=sam.iloc[:,0:2]

out=sam.iloc[:,-1]
out
inp
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(inp,out,test_size=0.2,random_state=20)
scaler=MinMaxScaler()
scaler.fit(x_train)

x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)
pd_scaled_train=pd.DataFrame(x_train_scaled)
pd_scaled_test=pd.DataFrame(x_test_scaled)
pd_scaled_train.head()
# Out:
#           0         1
# 0  0.406787  0.277778
# 1  0.572476  0.511111
# 2  0.746963  0.222222
# 3  0.143904  0.062222
# 4  0.264349  0.222222

# %%
pd_scaled_test.head()
# Out:
#           0         1
# 0  0.318601  0.333333
# 1  0.199623  0.000000
# 2  0.202974  0.136667
# 3  0.449937  0.111111
# 4  0.174068  0.111111
